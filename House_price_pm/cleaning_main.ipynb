# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %% [markdown]
# ## With the keywords loaded and exceptions

# %%
# import pandas as pd
# import re
# from tqdm import tqdm
#
# # --- CONFIG ---
# INPUT_FILE = "olx_land_sale.csv"
# OUTPUT_FILE = "dataset_with_price_text1.csv"
# TEXT_COLUMN = "description_"
# CONTEXT_WORDS = 3  # Number of words before and after
#
# def extract_price_with_context(text):
#     """
#     Extract price per land unit with 3 words before and after for context.
#     Returns None if no valid price pattern found.
#     """
#     if not isinstance(text, str) or text.strip() == "":
#         return None
#
#     # Clean up HTML tags but preserve text
#     text = re.sub(r'<br\s*/?>', ' ', text)
#     text = re.sub(r'<[^>]+>', '', text)
#     text = ' '.join(text.split())  # Normalize whitespace
#
#     # Patterns here:
#     patterns = [
#         #1: "22 000 за сотку" / "15000 за сотку"
#         r'(\d{3,}[\s,]*\d*)\s*(?:у\.е\.|usd|\$|доллар|dollar|ming|минг)?\s*(за|per|for)\s*(сотку|sotku|sotix|sot|сотих|сот|гектар|gektar)',
#
#         # 2: "сотиги 5500$" / "sotixi 20000"
#         r'(сотих[иы]|sotix[iy]|сот[иы]г[иы])\s*(\d{3,}[\s,]*\d*)\s*(?:\$|у\.е\.|usd|ming|минг|dollar)?',
#
#         # 3: "1 сотих 80.000 u.e" / "1 sotix 50000$"
#         r'(1\s*(?:сотку|сотих|сотка|sotix|sotku|sot))\s*(\d{3,}[\s,\.]*\d*)\s*(?:\$|у\.е\.|usd|ming|минг)?',
#
#         # 4: "цена 22 000 за сотку"
#         r'(цена|нарх[иы]?|price|cost)\s*:?\s*(\d{3,}[\s,]*\d*)\s*(?:\$|у\.е\.|usd|ming|минг)?\s*(за|per)\s*(сотку|sotix|сот)',
#
#         # 5: "5000 мингдан" (Uzbek "from price")
#         r'(\d{3,}[\s,]*\d*)\s*(ming|минг)(дан)',
#
#         # 6: "сотку: 15000" or "за сотку 20000"
#         r'(за|per)?\s*(сотку|сотих|sotix|sotku|сот)\s*[:-]?\s*(\d{4,}[\s,]*\d*)\s*(?:\$|у\.е\.|ming|минг|usd)?',
#     ]
#
#     best_match = None
#     best_match_pos = -1
#
#     for pattern in patterns:
#         matches = list(re.finditer(pattern, text, re.IGNORECASE))
#         for match in matches:
#             # Get the full matched text
#             matched_text = match.group(0)
#
#             # Filter out matches that are too short or just numbers
#             if len(matched_text.strip()) < 5:
#                 continue
#
#             # Check if this match contains actual price indicators
#             has_price_word = any(word in matched_text.lower() for word in
#                 ['сотку', 'sotix', 'сот', 'за', 'ming', 'минг', 'цена', 'нарх'])
#
#             if not has_price_word:
#                 continue
#
#             # Extract numbers and verify they're realistic prices
#             numbers = re.findall(r'\d+', matched_text.replace(' ', '').replace(',', ''))
#             if numbers:
#                 main_number = max(numbers, key=lambda x: len(x))
#                 # Filter unrealistic prices (too small)
#                 if len(main_number) < 3:
#                     continue
#
#             # Get context: 3 words before and after
#             start_pos = match.start()
#             end_pos = match.end()
#
#             # Find word boundaries before match
#             before_text = text[:start_pos]
#             before_words = before_text.split()[-CONTEXT_WORDS:]
#
#             # Find word boundaries after match
#             after_text = text[end_pos:]
#             after_words = after_text.split()[:CONTEXT_WORDS]
#
#             # Build context string
#             context = ' '.join(before_words + [matched_text] + after_words)
#
#             # Keep the first good match found (or prioritize by position)
#             if best_match is None or start_pos < best_match_pos:
#                 best_match = context.strip()
#                 best_match_pos = start_pos
#
#     return best_match if best_match else None
#
# # --- LOAD DATA ---
# print(" Loading data...")
# df = pd.read_csv(INPUT_FILE)
# total_rows = len(df)
# print(f"   Loaded {total_rows:,} rows")
#
# # --- PROCESS ---
# print(f"\n⚙ Processing all rows...")
# print(f"   Extracting price + {CONTEXT_WORDS} words before/after...")
# tqdm.pandas(desc="Extracting prices")
# df["price_text"] = df[TEXT_COLUMN].progress_apply(extract_price_with_context)
#
# # --- SAVE ---
# print(f"\n Saving results...")
# df.to_csv(OUTPUT_FILE, index=False)
#
# # --- STATISTICS ---
# found_count = df["price_text"].notna().sum()
# not_found = total_rows - found_count
#
# print(f"\n COMPLETE!")
# print(f"   ✓ Found prices: {found_count:,} rows ({found_count/total_rows*100:.1f}%)")
# print(f"   ✗ No price found: {not_found:,} rows ({not_found/total_rows*100:.1f}%)")
# print(f"    Saved to: {OUTPUT_FILE}")
#
# # --- SAMPLE RESULTS ---
# print("\n Sample extractions (first 15 with prices):")
# samples = df[df["price_text"].notna()].head(15)
# for idx, row in samples.iterrows():
#     print(f"\n   Row {idx}:")
#     print(f"   → {row['price_text']}")
#
# # --- SHOW ROWS WITHOUT PRICES ---
# print("\n\n Sample rows where NO price was found (first 5):")
# no_price = df[df["price_text"].isna()].head(5)
# for idx, row in no_price.iterrows():
#     preview = row[TEXT_COLUMN][:100].replace('\n', ' ')
#     print(f"\n   Row {idx}: {preview}...")
#
# print("\n\n Tips:")
# print("   • 'None' means no per-unit price was found")

# %% [markdown]
# ## Converting land_area to simply "acre", and leaving it as float

# %%
# Regional average prices dictionary (in USD)
regional_prices = {
    "город Ташкент": 1251.69,  # Price segment: 10
    "Самаркандская область": 753.03,  # Price segment: 6
    "Ташкентская область": 695.25,  # Price segment: 5
    "Навоийская область": 583.55,  # Price segment: 4
    "Наманганская область": 470.91,  # Price segment: 2
    "Джизакская область": 464.21,  # Price segment: 2
    "Сурхандарьинская область": 455.77,  # Price segment: 2
    "Бухарская область": 454.60,  # Price segment: 2
    "Ферганская область": 444.84,  # Price segment: 2
    "Кашкадарьинская область": 443.78,  # Price segment: 2
    "Сырдарьинская область": 436.73,  # Price segment: 2
    "Хорезмская область": 397.03,  # Price segment: 2
    "Республика Каракалпакстан": 390.10  # Price segment: 1
}

# df['price_per_m2'] = (df['price'] / df['land_area']).round(2)

# %%
# df["land_area"] = (
#     df["land_area"]
#     .astype(str)                             # ensure string type
#     .str.replace("соток", "", regex=False)   # remove the word
#     .str.replace(" ", "", regex=False)        # remove inner spaces (like in '1 000')
#     .str.strip()                              # trim spaces
#     .replace("", None)                        # replace empty strings
#     .astype(float)                            # convert to float
# )
# df['land_area'].head()

# %%
# df["price_per_area"] = df["price"] / df["land_area"]
# df['price_per_area'].value_counts()

# %%
# df['purpose'].value_counts()

# %% [markdown]
# ## Main cleaning

# %%
orig = pd.read_csv('olx_land_sale_orig.csv')
df = orig.copy()
df.rename(columns={'id_': 'id', 'url_':'url', 'title_': 'title', 'description_': 'description', 'status_': 'status', 'business_': 'business', 'last_refresh_time_': 'last_refresh_time', 'time__': 'time', 'price': 'price_usd', 'price_converted_value': 'price_uzs'}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 39 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              22000 non-null  int64
#  1   url                             22000 non-null  object
#  2   title                           22000 non-null  object
#  3   description                     22000 non-null  object
#  4   business                        22000 non-null  int64
#  5   user_name                       22000 non-null  object
#  6   category_id                     22000 non-null  int64
#  7   category_type                   22000 non-null  object
#  8   location_region_name            22000 non-null  object
#  9   location_city_name              22000 non-null  object
#  10  location_district_name          21996 non-null  object
#  11  last_refresh_time               22000 non-null  object
#  12  created_time_                   22000 non-null  object
#  13  valid_to_time_                  22000 non-null  object
#  14  pushup_time_                    8752 non-null   object
#  15  status                          22000 non-null  object
#  16  map_lat                         22000 non-null  float64
#  17  map_lon                         22000 non-null  float64
#  18  offer_type_                     22000 non-null  object
#  19  promotion_highlighted           22000 non-null  int64
#  20  promotion_urgent                22000 non-null  int64
#  21  promotion_top_ad                22000 non-null  int64
#  22  promotion_premium_ad_page       22000 non-null  int64
#  23  time                            22000 non-null  object
#  24  price_usd                       22000 non-null  float64
#  25  price_currency                  22000 non-null  object
#  26  price_arranged                  22000 non-null  int64
#  27  price_budget                    22000 non-null  int64
#  28  price_negotiable                22000 non-null  int64
#  29  price_uzs                       17681 non-null  float64
#  30  price_converted_currency        17681 non-null  object
#  31  price_previous_value            231 non-null    float64
#  32  price_converted_previous_value  209 non-null    float64
#  33  land_area                       21985 non-null  object
#  34  purpose                         21985 non-null  object
#  35  location                        21992 non-null  object
#  36  communications                  18401 non-null  object
#  37  comission                       22000 non-null  object
#  38  type_of_plot                    15326 non-null  object
# dtypes: float64(6), int64(10), object(23)
# memory usage: 6.5+ MB
# C:\Users\Saidakbar\AppData\Local\Temp\ipykernel_17448\1811184001.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   orig = pd.read_csv('olx_land_sale_orig.csv')

# %%
df.head()
# Out:
#          id                                                url  \
# 0  52891158  https://www.olx.uz/d/obyavlenie/kuruk-er-sotil...
# 1  51622740  https://www.olx.uz/d/obyavlenie/prodaetsya-uch...
# 2  48788994  https://www.olx.uz/d/obyavlenie/uch-kahramonda...
# 3  56466143  https://www.olx.uz/d/obyavlenie/kibray-tsentr-...
# 4  55098422  https://www.olx.uz/d/obyavlenie/srochno-uy-uri...
#
#                                                title  \
# 0  Курук ер сотилади 4 соту свет газ Сув интернет...
# 1  Продаётся участок в центре, 2.5 сотки,вдоль до...
# 2  Уч кахрамондан 4 км кирганда Гулистонда 2 ёки ...
# 3  Кибрай центр Продается земельный участок под с...
# 4               СРОЧНО!!! уй қуриш учун ер сотилади.
#
#                                          description  business  \
# 0  Ассалому алейкум Назарбекда<br />\n тукимачи м...         0
# 1  ПРОДАЖА УЧАСТКА <br />\nРайон: Яккасарайский,<...         1
# 2  Зудлик билан 2 ёки 4  сотих ер учаска сотилади...         0
# 3  Продаётся  земельный участок под строительство...         1
# 4  Қибрай тумани Ёшлик маҳалласида жуда зўр жойда...         0
#
#              user_name  category_id category_type location_region_name  \
# 0         998992332145           10   real_estate  Ташкентская область
# 1               Nigina           10   real_estate  Ташкентская область
# 2  Акбар Исмаилов 2111           10   real_estate  Ташкентская область
# 3                Хамза           10   real_estate  Ташкентская область
# 4               Алишер           10   real_estate  Ташкентская область
#
#   location_city_name  ...     price_uzs price_converted_currency  \
# 0           Назарбек  ...  2.718807e+08                      UZS
# 1            Ташкент  ...  3.304886e+09                      UZS
# 2            Ташкент  ...  2.764168e+08                      UZS
# 3             Кибрай  ...  2.821104e+08                      UZS
# 4             Кибрай  ...  5.801046e+08                      UZS
#
#   price_previous_value price_converted_previous_value   land_area  \
# 0                  NaN                            NaN     4 соток
# 1                  NaN                            NaN  2.50 соток
# 2                  NaN                            NaN    24 соток
# 3                  NaN                            NaN     7 соток
# 4                  NaN                            NaN     6 соток
#
#                    purpose                                           location  \
# 0                   Другое                                        В пригороде
# 1  Земля под строительство                             В городе, Вдоль трассы
# 2     Земля под сад/огород      В городе, На закрытой территории, В пригороде
# 3  Земля под строительство                                           В городе
# 4  Земля под строительство  Вдоль трассы, Возле водоема, реки, В дачном ма...
#
#                                       communications comission  type_of_plot
# 0                 Электричество, Газ, Вода, Интернет        Да           NaN
# 1   Электричество, Канализация, Газ, Вода, Отопление       Нет     Неделимый
# 2  Электричество, Телефон, Канализация, Газ, Вода...       Нет       Делимый
# 3              Электричество, Вода, Газ, Канализация       Нет     Неделимый
# 4                           Электричество, Вода, Газ       Нет       Делимый
#
# [5 rows x 39 columns]

# %%
df['offer_type_'].value_counts()
# Out:
# offer_type_
# offer    22000
# Name: count, dtype: int64

# %%
cols_to_drop = ['url', 'title', 'user_name', 'category_id', 'last_refresh_time', 'created_time_',
                'valid_to_time_', 'pushup_time_', 'status', 'map_lat', 'map_lon', 'offer_type_', 'price_previous_value',
                'price_converted_previous_value']
df.drop(cols_to_drop, axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         22000 non-null  int64
#  1   description                22000 non-null  object
#  2   business                   22000 non-null  int64
#  3   category_type              22000 non-null  object
#  4   location_region_name       22000 non-null  object
#  5   location_city_name         22000 non-null  object
#  6   location_district_name     21996 non-null  object
#  7   promotion_highlighted      22000 non-null  int64
#  8   promotion_urgent           22000 non-null  int64
#  9   promotion_top_ad           22000 non-null  int64
#  10  promotion_premium_ad_page  22000 non-null  int64
#  11  time                       22000 non-null  object
#  12  price_usd                  22000 non-null  float64
#  13  price_currency             22000 non-null  object
#  14  price_arranged             22000 non-null  int64
#  15  price_budget               22000 non-null  int64
#  16  price_negotiable           22000 non-null  int64
#  17  price_uzs                  17681 non-null  float64
#  18  price_converted_currency   17681 non-null  object
#  19  land_area                  21985 non-null  object
#  20  purpose                    21985 non-null  object
#  21  location                   21992 non-null  object
#  22  communications             18401 non-null  object
#  23  comission                  22000 non-null  object
#  24  type_of_plot               15326 non-null  object
# dtypes: float64(2), int64(9), object(14)
# memory usage: 4.2+ MB

# %%
df['time'] = pd.to_datetime(df['time'], format='%d_%m_%Y_%H_%M_%S').dt.normalize()

# %%
df.head()
# Out:
#          id                                        description  business  \
# 0  52891158  Ассалому алейкум Назарбекда<br />\n тукимачи м...         0
# 1  51622740  ПРОДАЖА УЧАСТКА <br />\nРайон: Яккасарайский,<...         1
# 2  48788994  Зудлик билан 2 ёки 4  сотих ер учаска сотилади...         0
# 3  56466143  Продаётся  земельный участок под строительство...         1
# 4  55098422  Қибрай тумани Ёшлик маҳалласида жуда зўр жойда...         0
#
#   category_type location_region_name location_city_name  \
# 0   real_estate  Ташкентская область           Назарбек
# 1   real_estate  Ташкентская область            Ташкент
# 2   real_estate  Ташкентская область            Ташкент
# 3   real_estate  Ташкентская область             Кибрай
# 4   real_estate  Ташкентская область             Кибрай
#
#   location_district_name  promotion_highlighted  promotion_urgent  \
# 0                      0                      0                 0
# 1    Яккасарайский район                      0                 0
# 2     Юнусабадский район                      1                 0
# 3                      0                      0                 0
# 4                      0                      0                 0
#
#    promotion_top_ad  ...  price_budget price_negotiable     price_uzs  \
# 0                 0  ...             0                1  2.718807e+08
# 1                 0  ...             0                1  3.304886e+09
# 2                 1  ...             0                1  2.764168e+08
# 3                 0  ...             0                1  2.821104e+08
# 4                 0  ...             0                1  5.801046e+08
#
#   price_converted_currency   land_area                  purpose  \
# 0                      UZS     4 соток                   Другое
# 1                      UZS  2.50 соток  Земля под строительство
# 2                      UZS    24 соток     Земля под сад/огород
# 3                      UZS     7 соток  Земля под строительство
# 4                      UZS     6 соток  Земля под строительство
#
#                                             location  \
# 0                                        В пригороде
# 1                             В городе, Вдоль трассы
# 2      В городе, На закрытой территории, В пригороде
# 3                                           В городе
# 4  Вдоль трассы, Возле водоема, реки, В дачном ма...
#
#                                       communications comission type_of_plot
# 0                 Электричество, Газ, Вода, Интернет        Да          NaN
# 1   Электричество, Канализация, Газ, Вода, Отопление       Нет    Неделимый
# 2  Электричество, Телефон, Канализация, Газ, Вода...       Нет      Делимый
# 3              Электричество, Вода, Газ, Канализация       Нет    Неделимый
# 4                           Электричество, Вода, Газ       Нет      Делимый
#
# [5 rows x 25 columns]

# %%
# Clean up of html leftovers
df['description'] = df['description'].str.replace(r'<br\s*/?>', '', regex=True)
df.head(5)
# Out:
#          id                                        description  business  \
# 0  52891158  Ассалому алейкум Назарбекда\n тукимачи маххала...         0
# 1  51622740  ПРОДАЖА УЧАСТКА \nРайон: Яккасарайский,\n   Ра...         1
# 2  48788994  Зудлик билан 2 ёки 4  сотих ер учаска сотилади...         0
# 3  56466143  Продаётся  земельный участок под строительство...         1
# 4  55098422  Қибрай тумани Ёшлик маҳалласида жуда зўр жойда...         0
#
#   category_type location_region_name location_city_name  \
# 0   real_estate  Ташкентская область           Назарбек
# 1   real_estate  Ташкентская область            Ташкент
# 2   real_estate  Ташкентская область            Ташкент
# 3   real_estate  Ташкентская область             Кибрай
# 4   real_estate  Ташкентская область             Кибрай
#
#   location_district_name  promotion_highlighted  promotion_urgent  \
# 0                      0                      0                 0
# 1    Яккасарайский район                      0                 0
# 2     Юнусабадский район                      1                 0
# 3                      0                      0                 0
# 4                      0                      0                 0
#
#    promotion_top_ad  ...  price_budget price_negotiable     price_uzs  \
# 0                 0  ...             0                1  2.718807e+08
# 1                 0  ...             0                1  3.304886e+09
# 2                 1  ...             0                1  2.764168e+08
# 3                 0  ...             0                1  2.821104e+08
# 4                 0  ...             0                1  5.801046e+08
#
#   price_converted_currency   land_area                  purpose  \
# 0                      UZS     4 соток                   Другое
# 1                      UZS  2.50 соток  Земля под строительство
# 2                      UZS    24 соток     Земля под сад/огород
# 3                      UZS     7 соток  Земля под строительство
# 4                      UZS     6 соток  Земля под строительство
#
#                                             location  \
# 0                                        В пригороде
# 1                             В городе, Вдоль трассы
# 2      В городе, На закрытой территории, В пригороде
# 3                                           В городе
# 4  Вдоль трассы, Возле водоема, реки, В дачном ма...
#
#                                       communications comission type_of_plot
# 0                 Электричество, Газ, Вода, Интернет        Да          NaN
# 1   Электричество, Канализация, Газ, Вода, Отопление       Нет    Неделимый
# 2  Электричество, Телефон, Канализация, Газ, Вода...       Нет      Делимый
# 3              Электричество, Вода, Газ, Канализация       Нет    Неделимый
# 4                           Электричество, Вода, Газ       Нет      Делимый
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Fill null values in the land_area, to catch its values from the description and fill it

# %%
# Clean extracted number: remove spaces, fix comma
def clean_number(val):
    if pd.isna(val):
        return val
    val = re.sub(r'\s+', '', str(val))  # remove all spaces
    val = val.replace(',', '.')         # standardize decimal
    return float(val)

# Use the improved pattern
num_pattern = r'\d{1,3}(?:\s\d{3})*(?:[.,]\d+)?'
pattern = rf'({num_pattern})\s*[сc][оo0][тtт]\w*'

mask = (
    df['land_area'].isnull() &
    df['description'].notnull() &
    df['description'].str.contains(pattern, regex=True, case=False)
)

extracted = df.loc[mask, 'description'].str.extract(pattern, flags=re.IGNORECASE)
df.loc[mask, 'land_area'] = extracted[0].apply(clean_number)
print(df[['land_area', 'description']].head(10))
print("Remaining nulls in land_area:", df['land_area'].isnull().sum())
# Out:
#      land_area                                        description
# 0      4 соток  Ассалому алейкум Назарбекда\n тукимачи маххала...
# 1   2.50 соток  ПРОДАЖА УЧАСТКА \nРайон: Яккасарайский,\n   Ра...
# 2     24 соток  Зудлик билан 2 ёки 4  сотих ер учаска сотилади...
# 3      7 соток  Продаётся  земельный участок под строительство...
# 4      6 соток  Қибрай тумани Ёшлик маҳалласида жуда зўр жойда...
# 5     40 соток  Продаётся земельный участок под производство и...
# 6      8 соток  Продаётся земельный участок с кадастром \nКибр...
# 7    150 соток  Продается база с земельным участок \nПаркентск...
# 8  1 000 соток  Представляю  Вашему Вниманию  Инвестиционное п...
# 9    600 соток  - 6 соток 20/30 метр.\n- 2 кават, 6 хона, 4 са...
# Remaining nulls in land_area: 7
# C:\Users\Saidakbar\AppData\Local\Temp\ipykernel_17448\1181913159.py:16: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df['description'].str.contains(pattern, regex=True, case=False)

# %% [markdown]
# ## Test4 21k

# %%
SOTIX_REGEX = re.compile(
    r'''
    # Match number (supports: 6, 2.5, 4,5, 1 200, 10.000)
    (?P<number1>\d{1,3}(?:\s?\d{3})*(?:[.,]\d+)?)
    \s*
    # Optional: range indicator (dash, "dan", "gacha", "–", etc.)
    (?:
        [-–—~]?\s*                     # dash or no dash
        (?:dan\s+)?                    # optional "dan"
        (?P<number2>\d{1,3}(?:\s?\d{3})*(?:[.,]\d+)?)?
        \s*
    )?
    # Flexible "sot" unit (covers ALL variants in your data)
    [сc][оo0][тtт]                    # "sot" in Cyrillic/Latin/OCR
    \s*
    # Optional suffixes (ix, ok, ik, ux, их, ок, их, ихлик, etc.)
    [a-zа-я]*[ixkгоуhъь]*             # covers sotix, sotok, sotik, sutox, sotux, sotig‘, sutuk, so’tix, soʻtik, etc.
    ''',
    re.IGNORECASE | re.VERBOSE
)


def extract_sotix_from_desc(desc):
    if pd.isna(desc):
        return None

    match = SOTIX_REGEX.search(str(desc))
    if not match:
        return None

    def clean_num(s):
        return float(s.replace(' ', '').replace(',', '.'))

    try:
        low = clean_num(match.group('number1'))
        high_str = match.group('number2')
        if high_str:
            high = clean_num(high_str)
            return (low + high) / 2.0
        else:
            return low
    except (ValueError, TypeError):
        return None

# %%
# Extract sotix from description
df['extracted_land_area'] = df['description'].apply(extract_sotix_from_desc)

# Fill ONLY nulls in land_area
df['land_area'] = df['land_area'].fillna(df['extracted_land_area'])

# %% [markdown]
# ## Test3 2k

# %%
# # Main regex pattern
# SOTIX_PATTERN = r'''
# (\d{1,3}(?:\s?\d{3})*(?:[.,]\d+)?)    # Group 1: number (6, 1 200, 2.5, 4,5)
# \s*                                    # optional space
# [-–—]?\s*                              # optional dash (for ranges)
# (?:dan\s+)?                            # optional "dan" (as in "6 dan 8")
# (\d{1,3}(?:\s?\d{3})*(?:[.,]\d+)?)?    # Group 2: second number (for ranges)
# \s*                                    # optional space
# [сc][оo0][тtт]                        # flexible "sot" (cyrillic/latin/zero)
# \s*[a-zа-я]*[ixkгоуh]*                # optional endings: ix, ok, ik, ux, их, ок
# '''
#
# # Compile with verbose and ignore case
# compiled_pattern = re.compile(SOTIX_PATTERN, re.IGNORECASE | re.VERBOSE)

# %%
# def extract_sotix(desc):
#     if pd.isna(desc):
#         return None
#
#     # Search for pattern
#     match = compiled_pattern.search(str(desc))
#     if not match:
#         return None
#
#     num1_str = match.group(1)
#     num2_str = match.group(2)
#
#     # Clean number: remove spaces, fix comma
#     def clean_num(s):
#         return float(s.replace(' ', '').replace(',', '.'))
#
#     try:
#         low = clean_num(num1_str)
#         if num2_str:  # It's a range like "2-4" or "6 dan 8"
#             high = clean_num(num2_str)
#             return (low + high) / 2.0
#         else:
#             return low
#     except (ValueError, TypeError):
#         return None

# %%
# # Create extracted column
# df['extracted_land_area'] = df['description'].apply(extract_sotix)
#
# # Fill ONLY nulls in land_area
# df['land_area'] = df['land_area'].fillna(df['extracted_land_area'])
#
# # Optional: drop helper column
# # df = df.drop(columns=['extracted_land_area'])

# %% [markdown]
# ## Test2 1.5k

# %%
# # Pattern to match:
# # - plain numbers: "6 sotix"
# # - ranges: "2-4 sotix", "6 dan 8 gacha", "5-6sotok"
# range_pattern = r'(\d+(?:[.,]\d+)?)(?:\s*[-–—]\s*|\s+dan\s+)(\d+(?:[.,]\d+)?)\s*[сc][оo0][тtт]\s*[a-zа-я]*[ixkгоуh]*'
#
# # Fallback: single number (your original case)
# single_pattern = r'(\d+(?:[.,]\d+)?(?:\s*\d{3})*(?:[.,]\d+)?)\s*[сc][оo0][тtт]\s*[a-zа-я]*[ixkгоуh]*'
#
# def extract_sotix_robust(desc):
#     if pd.isna(desc):
#         return None
#
#     desc = str(desc)
#
#     # First: try to match a RANGE
#     range_match = re.search(range_pattern, desc, re.IGNORECASE)
#     if range_match:
#         try:
#             low = float(range_match.group(1).replace(',', '.'))
#             high = float(range_match.group(2).replace(',', '.'))
#             return (low + high) / 2.0
#         except ValueError:
#             pass
#
#     # Second: try single number (with space support: "1 000")
#     single_match = re.search(single_pattern, desc, re.IGNORECASE)
#     if single_match:
#         num_str = single_match.group(1).replace(' ', '').replace(',', '.')
#         try:
#             return float(num_str)
#         except ValueError:
#             pass
#
#     return None

# %%
# df['extracted_land_area'] = df['description'].apply(extract_sotix_robust)
#
# # Fill ONLY the NaNs in land_area
# df['land_area'] = df['land_area'].fillna(df['extracted_land_area'])

# %% [markdown]
# ## Test1 500

# %%
# sotix_pattern = r'(\d{1,3}(?:\s?\d{3})*(?:[.,]\d+)?)\s*[сc][оo0][тtт]\s*[а-яa-z]*\s*[\d\w]*'
#
# # Explanation:
# # - \d{1,3}(?:\s?\d{3})* → matches 6, 1 200, 1200, 10 000
# # - [.,]\d+? → accepts 6.5 or 6,5
# # - [сc][оo0][тtт] → flexible "с/с", "о/o/0", "т/t"
# # - \s*[а-яa-z]*\s*[\d\w]* → matches endings like "их", "ok", "ka", "ux", "ig", etc.
#
#
# def extract_sotix(text):
#     if pd.isna(text):
#         return None
#     match = re.search(sotix_pattern, text, re.IGNORECASE)
#     if match:
#         num_str = match.group(1)
#         # Clean: remove spaces, replace comma with dot
#         num_clean = num_str.replace(' ', '').replace(',', '.')
#         try:
#             return float(num_clean)
#         except ValueError:
#             return None
#     return None

# %%
# # Create new column: extracted_land_area
# df['extracted_land_area'] = df['description'].apply(extract_sotix)
#
# # Optional: fill land_area if null (as you planned)
# mask = df['land_area'].isnull() & df['extracted_land_area'].notnull()
# df.loc[mask, 'land_area'] = df['extracted_land_area']
#
# # Check results
# print(df[['land_area', 'extracted_land_area', 'description']].head(10))
# print("Remaining nulls in land_area:", df['land_area'].isnull().sum())

# %%
df['description'][8]
# Out:
# 'Представляю  Вашему Вниманию  Инвестиционное предложение \n\nпод  застройку  любого типа недвижимости, ориентир Турбаза  "Золотой корабль. Рядом речка "Чирчик.\n\nЗемельный участок с кадастром \nВдоль дороги трасса Ташкент-Чарвак, Бостанлыкский район, 1 линия!!\n\nИмеется проект для зоны отдыха. \n\nИдеальное расположение  для:\nГостиницы \nЗоны отдыха \nАпарт отеля \nКоттеджа\nДачу \nСанатория\nКлиника\n1.05 гектар\nнебольшой торг  имеется !\n\nЦена - 735000у.е.\n\nТел:+99893-801-99-57 Рустам \nСпециалист  по  недвижимости.'

# %%
df.head()
# Out:
#          id                                        description  business  \
# 0  52891158  Ассалому алейкум Назарбекда\n тукимачи маххала...         0
# 1  51622740  ПРОДАЖА УЧАСТКА \nРайон: Яккасарайский,\n   Ра...         1
# 2  48788994  Зудлик билан 2 ёки 4  сотих ер учаска сотилади...         0
# 3  56466143  Продаётся  земельный участок под строительство...         1
# 4  55098422  Қибрай тумани Ёшлик маҳалласида жуда зўр жойда...         0
#
#   category_type location_region_name location_city_name  \
# 0   real_estate  Ташкентская область           Назарбек
# 1   real_estate  Ташкентская область            Ташкент
# 2   real_estate  Ташкентская область            Ташкент
# 3   real_estate  Ташкентская область             Кибрай
# 4   real_estate  Ташкентская область             Кибрай
#
#   location_district_name  promotion_highlighted  promotion_urgent  \
# 0                      0                      0                 0
# 1    Яккасарайский район                      0                 0
# 2     Юнусабадский район                      1                 0
# 3                      0                      0                 0
# 4                      0                      0                 0
#
#    promotion_top_ad  ...  price_negotiable     price_uzs  \
# 0                 0  ...                 1  2.718807e+08
# 1                 0  ...                 1  3.304886e+09
# 2                 1  ...                 1  2.764168e+08
# 3                 0  ...                 1  2.821104e+08
# 4                 0  ...                 1  5.801046e+08
#
#    price_converted_currency   land_area                  purpose  \
# 0                       UZS     4 соток                   Другое
# 1                       UZS  2.50 соток  Земля под строительство
# 2                       UZS    24 соток     Земля под сад/огород
# 3                       UZS     7 соток  Земля под строительство
# 4                       UZS     6 соток  Земля под строительство
#
#                                             location  \
# 0                                        В пригороде
# 1                             В городе, Вдоль трассы
# 2      В городе, На закрытой территории, В пригороде
# 3                                           В городе
# 4  Вдоль трассы, Возле водоема, реки, В дачном ма...
#
#                                       communications  comission type_of_plot  \
# 0                 Электричество, Газ, Вода, Интернет         Да          NaN
# 1   Электричество, Канализация, Газ, Вода, Отопление        Нет    Неделимый
# 2  Электричество, Телефон, Канализация, Газ, Вода...        Нет      Делимый
# 3              Электричество, Вода, Газ, Канализация        Нет    Неделимый
# 4                           Электричество, Вода, Газ        Нет      Делимый
#
#   extracted_land_area
# 0                 4.0
# 1                 2.5
# 2                 4.0
# 3                 7.0
# 4                 8.0
#
# [5 rows x 26 columns]

# %%
df['land_area'].value_counts()
# Out:
# land_area
# 6 соток        2913
# 4 соток        1875
# 8 соток        1455
# 10 соток       1160
# 5 соток        1032
#                ...
# 6.84 соток        1
# 5.25 соток        1
# 16.74 соток       1
# 4.33 соток        1
# 288 соток         1
# Name: count, Length: 867, dtype: int64

# %%
df['extracted_land_area'].value_counts()
# Out:
# extracted_land_area
# 6.00     1399
# 4.00      905
# 8.00      622
# 10.00     525
# 5.00      428
#          ...
# 0.72        1
# 8.25        1
# 23.70       1
# 6.17        1
# 39.00       1
# Name: count, Length: 461, dtype: int64

# %%
df.info()
df[['land_area', 'extracted_land_area']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         22000 non-null  int64
#  1   description                22000 non-null  object
#  2   business                   22000 non-null  int64
#  3   category_type              22000 non-null  object
#  4   location_region_name       22000 non-null  object
#  5   location_city_name         22000 non-null  object
#  6   location_district_name     21996 non-null  object
#  7   promotion_highlighted      22000 non-null  int64
#  8   promotion_urgent           22000 non-null  int64
#  9   promotion_top_ad           22000 non-null  int64
#  10  promotion_premium_ad_page  22000 non-null  int64
#  11  time                       22000 non-null  datetime64[ns]
#  12  price_usd                  22000 non-null  float64
#  13  price_currency             22000 non-null  object
#  14  price_arranged             22000 non-null  int64
#  15  price_budget               22000 non-null  int64
#  16  price_negotiable           22000 non-null  int64
#  17  price_uzs                  17681 non-null  float64
#  18  price_converted_currency   17681 non-null  object
#  19  land_area                  21993 non-null  object
#  20  purpose                    21985 non-null  object
#  21  location                   21992 non-null  object
#  22  communications             18401 non-null  object
#  23  comission                  22000 non-null  object
#  24  type_of_plot               15326 non-null  object
#  25  extracted_land_area        9215 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(9), object(13)
# memory usage: 4.4+ MB
#          land_area  extracted_land_area
# 0          4 соток                  4.0
# 1       2.50 соток                  2.5
# 2         24 соток                  4.0
# 3          7 соток                  7.0
# 4          6 соток                  8.0
# ...            ...                  ...
# 21995    600 соток                  NaN
# 21996  1 100 соток                  NaN
# 21997    200 соток                  NaN
# 21998      6 соток                  NaN
# 21999    800 соток                  NaN
#
# [22000 rows x 2 columns]

# %%
df['land_area'].value_counts()
df['extracted_land_area'].value_counts()
# Out:
# extracted_land_area
# 6.00     1399
# 4.00      905
# 8.00      622
# 10.00     525
# 5.00      428
#          ...
# 0.72        1
# 8.25        1
# 23.70       1
# 6.17        1
# 39.00       1
# Name: count, Length: 461, dtype: int64

# %%
df['extracted_land_area']
# Out:
# 0        4.0
# 1        2.5
# 2        4.0
# 3        7.0
# 4        8.0
#         ...
# 21995    NaN
# 21996    NaN
# 21997    NaN
# 21998    NaN
# 21999    NaN
# Name: extracted_land_area, Length: 22000, dtype: float64

# %%
df['land_area']=df['land_area'].str.split(' ').str[0]

# %%
df['extracted_land_area'].isna().sum()
# Out:
# np.int64(12785)

# %%
df = df[df['extracted_land_area'].isna()]

# %%
df['land_area'] = pd.to_numeric(df['land_area'],errors='coerce')

# %%
df['land_diff'] = df['extracted_land_area']-df['land_area']

# %%
pd.set_option('display.max_rows',100)
df.head(100)
# Out:
#            id                                        description  business  \
# 7    55776194  Продается база с земельным участок \nПаркентск...         1
# 29                           Другое
# 30                           Другое
# 32          Земля под строительство
# 34          Земля под строительство
# 37                           Другое
# 39                           Другое
# 40          Земля под строительство
# 43          Земля под строительство
# 48                           Другое
# 50          Земля под строительство
# 51          Земля под строительство
# 53          Земля под строительство
# 56                           Другое
# 57          Земля под строительство
# 58          Земля под строительство
# 61                           Другое
# 64          Земля под строительство
# 65          Земля под строительство
# 66          Земля под строительство
# 68          Земля под строительство
# 69          Земля под строительство
# 72             Земля под сад/огород
# 82          Земля под строительство
# 83          Земля под строительство
# 85   Земля промышленного назначения
# 90          Земля под строительство
# 96          Земля под строительство
# 98          Земля под строительство
# 99          Земля под строительство
# 100         Земля под строительство
# 104         Земля под строительство
# 108            Земля под сад/огород
# 109         Земля под строительство
# 110         Земля под строительство
# 111         Земля под строительство
# 112         Земля под строительство
# 114         Земля под строительство
# 115                          Другое
# 117         Земля под строительство
# 118         Земля под строительство
# 121         Земля под строительство
# 123                          Другое
# 124         Земля под строительство
# 126                          Другое
# 127         Земля под строительство
# 129         Земля под строительство
# 131                          Другое
# 132         Земля под строительство
# 142                          Другое
# 147                          Другое
# 150         Земля под строительство
# 153         Земля под строительство
# 155         Земля под строительство
# 156            Земля под сад/огород
# 157                          Другое
# 158                          Другое
# 159         Земля под строительство
# 161         Земля под строительство
# 162         Земля под строительство
# 163         Земля под строительство
# 164         Земля под строительство
# 168         Земля под строительство
# 170            Земля под сад/огород
# 171            Земля под сад/огород
# 172                             NaN
# 173         Земля под строительство
# 174         Земля под строительство
# 178         Земля под строительство
# 179         Земля под строительство
# 180                          Другое
# 181         Земля под строительство
# 187         Земля под строительство
# 188         Земля под строительство
# 194         Земля под строительство
# 196         Земля под строительство
# 199  Земля промышленного назначения
# 207         Земля под строительство
# 209                          Другое
# 210         Земля под строительство
# 211         Земля под строительство
# 213         Земля под строительство
# 215         Земля под строительство
# 216                          Другое
# 218                          Другое
# 220            Земля под сад/огород
# 221         Земля под строительство
# 226                          Другое
# 229         Земля под строительство
# 233         Земля под строительство
# 237         Земля под строительство
# 238         Земля под строительство
# 239         Земля под строительство
# 241         Земля под строительство
# 243            Земля под сад/огород
# 244                          Другое
#
#                                               location  \
# 7                                В городе, В пригороде
# 8                    Вдоль трассы, Возле водоема, реки
# 10                           В пригороде, Вдоль трассы
# 16                                            В городе
# 28                                         В пригороде
# 29                                В сельской местности
# 30                                         В пригороде
# 32                  В сельской местности, В предгорьях
# 34                                         В пригороде
# 37                                            В городе
# 39                                        Вдоль трассы
# 40                              На закрытой территории
# 43                                            В городе
# 48                   В пригороде, В сельской местности
# 50                                 Возле водоема, реки
# 51                                В сельской местности
# 53                                            В городе
# 56                                            В городе
# 57                                            В городе
# 58                                         В пригороде
# 61                                            В городе
# 64                                    В дачном массиве
# 65                                            В городе
# 66                                            В городе
# 68                                            В городе
# 69                                            В городе
# 72                                    В дачном массиве
# 82                                            В городе
# 83                                         В пригороде
# 85                                         В пригороде
# 90                               В городе, В пригороде
# 96                                            В городе
# 98                                            В городе
# 99   В пригороде, Вдоль трассы, В дачном массиве, В...
# 100                                        В пригороде
# 104                                           В городе
# 108                                           В городе
# 109                                        В пригороде
# 110        В городе, Вдоль трассы, Возле водоема, реки
# 111                                           В городе
# 112                                Возле водоема, реки
# 114                                           В городе
# 115                                           В городе
# 117                                        В пригороде
# 118                                        В пригороде
# 121                             В городе, Вдоль трассы
# 123                               В сельской местности
# 124                               В сельской местности
# 126                                        В пригороде
# 127                                        В пригороде
# 129                                        В пригороде
# 131                                   В дачном массиве
# 132                               В сельской местности
# 142                                           В городе
# 147                                        В пригороде
# 150                                        В пригороде
# 153                                        В пригороде
# 155                                           В городе
# 156                                        В пригороде
# 157                                        В пригороде
# 158                                        В пригороде
# 159                                        В пригороде
# 161                          В пригороде, Вдоль трассы
# 162                               В сельской местности
# 163                          В пригороде, Вдоль трассы
# 164                                           В городе
# 168                  В пригороде, В сельской местности
# 170                В пригороде, На закрытой территории
# 171  В городе, Вдоль трассы, В пригороде, В дачном ...
# 172                                       Вдоль трассы
# 173                                           В городе
# 174                              В городе, В пригороде
# 178                                           В городе
# 179                                           В городе
# 180                                       Вдоль трассы
# 181  В пригороде, В дачном массиве, В сельской мест...
# 187                              В городе, В пригороде
# 188                                           В городе
# 194                                       Вдоль трассы
# 196                             В городе, Вдоль трассы
# 199                                           В городе
# 207                                           В городе
# 209                                        В пригороде
# 210                              В городе, В пригороде
# 211                                           В городе
# 213                                           В городе
# 215                                   В дачном массиве
# 216                                   В дачном массиве
# 218                                           В городе
# 220                                        В пригороде
# 221                                       Вдоль трассы
# 226                               В сельской местности
# 229                             В городе, Вдоль трассы
# 233                                        В пригороде
# 237                                           В городе
# 238                                        В пригороде
# 239                                        В пригороде
# 241                                        В пригороде
# 243                               В сельской местности
# 244                                        В пригороде
#
#                                         communications  comission  \
# 7                                                  NaN        Нет
# 8                                                  NaN        Нет
# 10         Электричество, Телефон, Газ, Вода, Интернет        Нет
# 16    Электричество, Канализация, Газ, Вода, Отопление        Нет
# 28       Электричество, Интернет, Газ, Вода, Отопление        Нет
# 29                            Электричество, Газ, Вода        Нет
# 30   Электричество, Телефон, Канализация, Газ, Вода...        Нет
# 32                            Электричество, Газ, Вода        Нет
# 34         Электричество, Телефон, Газ, Вода, Интернет        Нет
# 37         Электричество, Телефон, Газ, Вода, Интернет         Да
# 39                                                 NaN         Да
# 40                                           Вода, Газ         Да
# 43               Электричество, Газ, Вода, Канализация         Да
# 48                            Электричество, Вода, Газ         Да
# 50         Электричество, Телефон, Газ, Вода, Интернет         Да
# 51                            Электричество, Вода, Газ        Нет
# 53                  Электричество, Газ, Вода, Интернет        Нет
# 56                                                 NaN         Да
# 57   Электричество, Телефон, Канализация, Газ, Вода...        Нет
# 58                            Электричество, Газ, Вода        Нет
# 61                            Электричество, Газ, Вода        Нет
# 64                                 Электричество, Вода        Нет
# 65   Электричество, Интернет, Газ, Вода, Телефон, О...        Нет
# 66               Электричество, Газ, Вода, Канализация        Нет
# 68   Электричество, Интернет, Газ, Вода, Телефон, К...         Да
# 69               Электричество, Газ, Вода, Канализация        Нет
# 72                                       Электричество        Нет
# 82   Электричество, Телефон, Канализация, Газ, Вода...         Да
# 83                                                 NaN        Нет
# 85         Электричество, Телефон, Газ, Вода, Интернет        Нет
# 90                                                 NaN         Да
# 96   Электричество, Вода, Газ, Отопление, Канализац...        Нет
# 98   Канализация, Вода, Интернет, Газ, Электричеств...         Да
# 99                  Электричество, Газ, Вода, Интернет        Нет
# 100  Электричество, Вода, Газ, Отопление, Интернет,...        Нет
# 104                Отопление, Вода, Газ, Электричество        Нет
# 108                           Электричество, Газ, Вода         Да
# 109      Электричество, Вода, Газ, Отопление, Интернет         Да
# 110                                                NaN        Нет
# 111                           Газ, Вода, Электричество        Нет
# 112              Электричество, Газ, Вода, Канализация        Нет
# 114  Электричество, Телефон, Канализация, Газ, Вода...        Нет
# 115  Отопление, Канализация, Электричество, Интерне...         Да
# 117        Электричество, Телефон, Газ, Вода, Интернет        Нет
# 118                           Электричество, Газ, Вода        Нет
# 121  Канализация, Вода, Интернет, Газ, Электричеств...        Нет
# 123                           Электричество, Газ, Вода        Нет
# 124              Электричество, Интернет, Газ, Телефон        Нет
# 126  Электричество, Телефон, Канализация, Газ, Вода...        Нет
# 127        Электричество, Телефон, Газ, Вода, Интернет        Нет
# 129  Электричество, Вода, Газ, Канализация, Интерне...        Нет
# 131                                                NaN         Да
# 132        Электричество, Вода, Газ, Интернет, Телефон        Нет
# 142                 Электричество, Газ, Вода, Интернет         Да
# 147                                 Электричество, Газ        Нет
# 150                 Электричество, Газ, Вода, Интернет         Да
# 153                           Электричество, Газ, Вода         Да
# 155        Электричество, Телефон, Газ, Вода, Интернет        Нет
# 156      Электричество, Интернет, Газ, Вода, Отопление         Да
# 157  Электричество, Интернет, Газ, Вода, Телефон, О...         Да
# 158                           Электричество, Газ, Вода        Нет
# 159  Электричество, Телефон, Канализация, Газ, Вода...        Нет
# 161  Электричество, Интернет, Газ, Вода, Телефон, О...        Нет
# 162                 Электричество, Вода, Газ, Интернет        Нет
# 163              Электричество, Газ, Вода, Канализация        Нет
# 164  Электричество, Телефон, Канализация, Газ, Вода...         Да
# 168                 Электричество, Газ, Вода, Интернет        Нет
# 170                 Электричество, Вода, Газ, Интернет         Да
# 171  Электричество, Телефон, Канализация, Газ, Вода...         Да
# 172                                                NaN         Да
# 173  Отопление, Канализация, Электричество, Интерне...        Нет
# 174                           Электричество, Газ, Вода        Нет
# 178                Отопление, Вода, Газ, Электричество        Нет
# 179  Электричество, Телефон, Канализация, Газ, Вода...         Да
# 180  Электричество, Телефон, Канализация, Газ, Вода...         Да
# 181        Электричество, Телефон, Газ, Вода, Интернет         Да
# 187  Электричество, Интернет, Газ, Вода, Телефон, К...         Да
# 188  Электричество, Интернет, Газ, Вода, Телефон, К...        Нет
# 194              Электричество, Газ, Вода, Канализация         Да
# 196  Отопление, Канализация, Электричество, Интерне...        Нет
# 199              Электричество, Газ, Вода, Канализация        Нет
# 207                 Электричество, Газ, Вода, Интернет        Нет
# 209                 Электричество, Газ, Вода, Интернет        Нет
# 210                  Электричество, Газ, Вода, Телефон         Да
# 211  Электричество, Интернет, Газ, Вода, Телефон, О...         Да
# 213  Отопление, Канализация, Электричество, Интерне...        Нет
# 215                                                NaN        Нет
# 216  Отопление, Вода, Газ, Электричество, Интернет,...        Нет
# 218  Электричество, Телефон, Канализация, Газ, Вода...        Нет
# 220                                Электричество, Вода        Нет
# 221                           Электричество, Газ, Вода        Нет
# 226        Электричество, Телефон, Газ, Вода, Интернет        Нет
# 229        Электричество, Вода, Газ, Интернет, Телефон        Нет
# 233                 Электричество, Газ, Вода, Интернет        Нет
# 237                 Электричество, Газ, Вода, Интернет        Нет
# 238                                                NaN         Да
# 239        Электричество, Телефон, Газ, Вода, Интернет        Нет
# 241  Электричество, Телефон, Канализация, Газ, Вода...         Да
# 243  Электричество, Телефон, Отопление, Вода, Интернет        Нет
# 244                                                NaN        Нет
#
#      type_of_plot extracted_land_area  land_diff
# 7       Неделимый                 NaN        NaN
# 8       Неделимый                 NaN        NaN
# 10      Неделимый                 NaN        NaN
# 16      Неделимый                 NaN        NaN
# 28      Неделимый                 NaN        NaN
# 29        Делимый                 NaN        NaN
# 30        Делимый                 NaN        NaN
# 32            NaN                 NaN        NaN
# 34      Неделимый                 NaN        NaN
# 37        Делимый                 NaN        NaN
# 39            NaN                 NaN        NaN
# 40            NaN                 NaN        NaN
# 43            NaN                 NaN        NaN
# 48            NaN                 NaN        NaN
# 50        Делимый                 NaN        NaN
# 51        Делимый                 NaN        NaN
# 53            NaN                 NaN        NaN
# 56            NaN                 NaN        NaN
# 57        Делимый                 NaN        NaN
# 58            NaN                 NaN        NaN
# 61      Неделимый                 NaN        NaN
# 64      Неделимый                 NaN        NaN
# 65      Неделимый                 NaN        NaN
# 66      Неделимый                 NaN        NaN
# 68      Неделимый                 NaN        NaN
# 69        Делимый                 NaN        NaN
# 72            NaN                 NaN        NaN
# 82      Неделимый                 NaN        NaN
# 83            NaN                 NaN        NaN
# 85      Неделимый                 NaN        NaN
# 90      Неделимый                 NaN        NaN
# 96      Неделимый                 NaN        NaN
# 98        Делимый                 NaN        NaN
# 99            NaN                 NaN        NaN
# 100       Делимый                 NaN        NaN
# 104           NaN                 NaN        NaN
# 108       Делимый                 NaN        NaN
# 109       Делимый                 NaN        NaN
# 110           NaN                 NaN        NaN
# 111       Делимый                 NaN        NaN
# 112     Неделимый                 NaN        NaN
# 114       Делимый                 NaN        NaN
# 115       Делимый                 NaN        NaN
# 117       Делимый                 NaN        NaN
# 118       Делимый                 NaN        NaN
# 121       Делимый                 NaN        NaN
# 123       Делимый                 NaN        NaN
# 124           NaN                 NaN        NaN
# 126       Делимый                 NaN        NaN
# 127       Делимый                 NaN        NaN
# 129           NaN                 NaN        NaN
# 131           NaN                 NaN        NaN
# 132     Неделимый                 NaN        NaN
# 142           NaN                 NaN        NaN
# 147     Неделимый                 NaN        NaN
# 150       Делимый                 NaN        NaN
# 153       Делимый                 NaN        NaN
# 155       Делимый                 NaN        NaN
# 156       Делимый                 NaN        NaN
# 157           NaN                 NaN        NaN
# 158           NaN                 NaN        NaN
# 159     Неделимый                 NaN        NaN
# 161       Делимый                 NaN        NaN
# 162       Делимый                 NaN        NaN
# 163     Неделимый                 NaN        NaN
# 164       Делимый                 NaN        NaN
# 168           NaN                 NaN        NaN
# 170       Делимый                 NaN        NaN
# 171       Делимый                 NaN        NaN
# 172           NaN                 NaN        NaN
# 173       Делимый                 NaN        NaN
# 174           NaN                 NaN        NaN
# 178       Делимый                 NaN        NaN
# 179     Неделимый                 NaN        NaN
# 180       Делимый                 NaN        NaN
# 181           NaN                 NaN        NaN
# 187       Делимый                 NaN        NaN
# 188       Делимый                 NaN        NaN
# 194       Делимый                 NaN        NaN
# 196           NaN                 NaN        NaN
# 199     Неделимый                 NaN        NaN
# 207       Делимый                 NaN        NaN
# 209       Делимый                 NaN        NaN
# 210       Делимый                 NaN        NaN
# 211           NaN                 NaN        NaN
# 213       Делимый                 NaN        NaN
# 215       Делимый                 NaN        NaN
# 216     Неделимый                 NaN        NaN
# 218     Неделимый                 NaN        NaN
# 220       Делимый                 NaN        NaN
# 221     Неделимый                 NaN        NaN
# 226           NaN                 NaN        NaN
# 229           NaN                 NaN        NaN
# 233           NaN                 NaN        NaN
# 237     Неделимый                 NaN        NaN
# 238           NaN                 NaN        NaN
# 239       Делимый                 NaN        NaN
# 241       Делимый                 NaN        NaN
# 243     Неделимый                 NaN        NaN
# 244     Неделимый                 NaN        NaN
#
# [100 rows x 27 columns]

# %%
df[['land_area','extracted_land_area','description']]
# Out:
#        land_area  extracted_land_area  \
# 7          150.0                  NaN
# 8            1.0                  NaN
# 10           3.0                  NaN
# 16         300.0                  NaN
# 28           5.5                  NaN
# ...          ...                  ...
# 21995      600.0                  NaN
# 21996        1.0                  NaN
# 21997      200.0                  NaN
# 21998        6.0                  NaN
# 21999      800.0                  NaN
#
#                                              description
# 7      Продается база с земельным участок \nПаркентск...
# 8      Представляю  Вашему Вниманию  Инвестиционное п...
# 10     Продается срочно земля 3 ст\nБуссув чаманзор м...
# 16     ПРОДАЖА ЗЕМЛИ\nПОД СТРОИТЕЛЬСТВО ЖК\nСЕРГЕЛИ Х...
# 28     Дачний участка зангатинскийрайон катартал буш ...
# ...                                                  ...
# 21995  Urganch tumani gʻallab mahallasi hayvat qishlo...
# 21996  Урганч шахар санотчилар кучасида 1100кв цемент...
# 21997  Гулистон махалласи Дурдона кучаси жасмин магаз...
# 21998  Срочно сотилоди бохосини\n галиштирип бараман ...
# 21999  800 квадрат турар жой урни сотилади.докумети т...
#
# [12785 rows x 3 columns]

# %%
df.loc[21995]['description']
# Out:
# 'Urganch tumani gʻallab mahallasi hayvat qishlogʻi Joy oʻrin sotiladi 600 kvadrat murojat uchun tel 880091005 narxiga keladon bolsak 30 million oxrgi baxosi'
